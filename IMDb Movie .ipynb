# %% [markdown]
# # <font color = blue> IMDb Movie Assignment </font>
#
# We have the data for the 100 top-rated movies from the past decade along with various pieces of information about the movie, its actors, and the voters who have rated these movies online. We will try to find some interesting insights into these movies and their voters, using Python.

# %%
# Filtering out the warnings

import warnings

warnings.filterwarnings('ignore')

# %%
# Importing the required libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ##  Task 1: Reading the data

# %% [markdown]
# - ### 1.1: Read the Movies Data.
#
# Reading the movies data file provided and store it in a dataframe `movies`.

# %%
# Reading the csv file using 'read_csv'.

movies = pd.read_csv("Movie+Assignment+Data.csv")

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

movies.head()
# Out:
#                    Title  title_year     budget      Gross      actor_1_name  \
# 0             La La Land        2016   30000000  151101803      Ryan Gosling
# 1               Zootopia        2016  150000000  341268248  Ginnifer Goodwin
# 2                   Lion        2016   12000000   51738905         Dev Patel
# 3                Arrival        2016   47000000  100546139         Amy Adams
# 4  Manchester by the Sea        2016    9000000   47695371     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone       Amiée Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating    genre_1  \
# ...

# %% [markdown]
# - ### 1.2: Inspecting the Dataframe
#
# Inspecting the dataframe for dimensions, null-values, and summary of different numeric columns.

# %%
# Checking the number of rows and columns in the dataframe

movies.shape
# Out:
# (100, 62)

# %%
# Checking the column-wise info of the dataframe

movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   100 non-null    object
#  1   title_year              100 non-null    int64
#  2   budget                  100 non-null    int64
#  3   Gross                   100 non-null    int64
#  4   actor_1_name            100 non-null    object
#  5   actor_2_name            100 non-null    object
#  6   actor_3_name            100 non-null    object
#  7   actor_1_facebook_likes  100 non-null    int64
#  8   actor_2_facebook_likes  99 non-null     float64
#  9   actor_3_facebook_likes  98 non-null     float64
#  10  IMDb_rating             100 non-null    float64
#  11  genre_1                 100 non-null    object
#  12  genre_2                 97 non-null     object
#  13  genre_3                 74 non-null     object
# ...

# %%
# Checking the summary for the numeric columns 

movies.describe()
# Out:
#         title_year        budget         Gross  actor_1_facebook_likes  \
# count   100.000000  1.000000e+02  1.000000e+02              100.000000
# mean   2012.820000  7.838400e+07  1.468679e+08            13407.270000
# std       1.919491  7.445295e+07  1.454004e+08            10649.037862
# min    2010.000000  3.000000e+06  2.238380e+05               39.000000
# 25%    2011.000000  1.575000e+07  4.199752e+07             1000.000000
# 50%    2013.000000  4.225000e+07  1.070266e+08            13000.000000
# 75%    2014.000000  1.500000e+08  2.107548e+08            20000.000000
# max    2016.000000  2.600000e+08  9.366622e+08            35000.000000
#
#        actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating  \
# count               99.000000               98.000000   100.000000
# mean              7377.303030             3002.153061     7.883000
# std              13471.568216             6940.301133     0.247433
# ...

# %% [markdown]
# ##  2: Data Analysis
#
# Now that we have loaded the dataset and inspected it, we see that most of the data is in place. As of now, no data cleaning is required, so let's start with some data manipulation, analysis, and visualisation to get various insights about the data.

# %% [markdown]
# -  ### 2.1: Reducing those Digits!
#
# Numbers in the `budget` and `gross` are too big, compromising its readability. Let's convert the unit of the `budget` and `gross` columns from `$` to `million $` first.

# %%
# Divide the 'gross' and 'budget' columns by 1000000 to convert '$' to 'million $'

movies.budget = movies.budget/(1000000)

movies.Gross = movies.Gross/(1000000)

# movies = movies.rename(columns = {'Gross': 'Gross Million $','budget':'budget Million $'}, inplace = True)

movies.head()
# Out:
#                    Title  title_year  budget       Gross      actor_1_name  \
# 0             La La Land        2016    30.0  151.101803      Ryan Gosling
# 1               Zootopia        2016   150.0  341.268248  Ginnifer Goodwin
# 2                   Lion        2016    12.0   51.738905         Dev Patel
# 3                Arrival        2016    47.0  100.546139         Amy Adams
# 4  Manchester by the Sea        2016     9.0   47.695371     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone       Amiée Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating    genre_1  \
# ...

# %% [markdown]
# -  ### 2.2: Let's Talk Profit!
#
# Let's check Profit for movies.

# %%
# Creating the new column named 'profit' by subtracting the 'budget' column from the 'gross' column

movies['profit'] = movies['Gross'] - movies['budget']

movies.head()
# Out:
#                    Title  title_year  budget       Gross      actor_1_name  \
# 0             La La Land        2016    30.0  151.101803      Ryan Gosling
# 1               Zootopia        2016   150.0  341.268248  Ginnifer Goodwin
# 2                   Lion        2016    12.0   51.738905         Dev Patel
# 3                Arrival        2016    47.0  100.546139         Amy Adams
# 4  Manchester by the Sea        2016     9.0   47.695371     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone       Amiée Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating    genre_1  \
# ...

# %%
# Sorting the dataframe with the 'profit' column as reference using the 'sort_values' function. 

movies.sort_values("profit", ascending = False, inplace = True, ignore_index = True)
movies.head()
# Out:
#                                         Title  title_year  budget       Gross  \
# 0  Star Wars: Episode VII - The Force Awakens        2015   245.0  936.662225
# 1                                The Avengers        2012   220.0  623.279547
# 2                                    Deadpool        2016    58.0  363.024263
# 3             The Hunger Games: Catching Fire        2013   130.0  424.645577
# 4                                 Toy Story 3        2010   200.0  414.984497
#
#         actor_1_name       actor_2_name           actor_3_name  \
# 0        Doug Walker         Rob Walker                      0
# 1    Chris Hemsworth  Robert Downey Jr.     Scarlett Johansson
# 2      Ryan Reynolds          Ed Skrein         Stefan Kapicic
# 3  Jennifer Lawrence    Josh Hutcherson  Sandra Ellis Lafferty
# 4          Tom Hanks  John Ratzenberger            Don Rickles
#
#    actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# ...

# %%
# The top 10 profitable movies by using position based indexing.

top10 = movies.iloc[:10, ]
top10
# Out:
#                                         Title  title_year  budget       Gross  \
# 0  Star Wars: Episode VII - The Force Awakens        2015   245.0  936.662225
# 1                                The Avengers        2012   220.0  623.279547
# 2                                    Deadpool        2016    58.0  363.024263
# 3             The Hunger Games: Catching Fire        2013   130.0  424.645577
# 4                                 Toy Story 3        2010   200.0  414.984497
# 5                       The Dark Knight Rises        2012   250.0  448.130642
# 6                              The Lego Movie        2014    60.0  257.756197
# 7                                    Zootopia        2016   150.0  341.268248
# 8                               Despicable Me        2010    69.0  251.501645
# 9                                  Inside Out        2015   175.0  356.454367
#
#         actor_1_name       actor_2_name           actor_3_name  \
# ...

# %%
# Plot profit vs budget

plt.figure(figsize = [10,8])
plt.scatter(movies.profit, movies.budget, color = 'cyan', edgecolor = 'Black')

plt.title("Profit Vs. Budget for Movies", fontdict = {'fontsize': 20, 'fontweight' : 10, 'color' : 'Green'})
plt.xlabel('Profit in Million $', fontdict = {'fontsize' : 15, 'fontweight' : 5, 'color' :  'Blue'})
plt.ylabel('Budget in Million $', fontdict = {'fontsize' : 15, 'fontweight': 5, 'color' : 'Blue'})

tick_values = np.arange(-100,800, 100)
tick_labels = ["-100M", "0","100M","200M","300M","400M","500M","600M","700M"]
tick_values_1 = np.arange(0,300, 50)
tick_labels_1 = ["0", "50M","100M","150M","200M","250M"]

plt.xticks(tick_values, tick_labels)
plt.yticks(tick_values_1, tick_labels_1)
plt.show()

# %% [markdown]
# #### Observations:
# - Most of the movies grouped between 0-50 Millions for Budget and 0-100 Millions for Profit.
# - For some movies that have low to high budget shows loss or negative profit
# - For Higher budget, profit does not shows positive slops except some outliers
# - Profit increases, as budget increases
# - for low budget movies success rate is moderately high then mid and high budget movies.

# %% [markdown]
# The dataset contains the 100 best performing movies from the year 2010 to 2016. However scatter plot tells a different story. we can notice that there are some movies with negative profit. Although good movies do incur losses, but there appear to be quite a few movie with losses.

# %%
#Finding the movies with negative profit

neg_profit = movies[movies['profit'] < 0]

neg_profit.head()
# Out:
#                       Title  title_year  budget      Gross      actor_1_name  \
# 89  Tucker and Dale vs Evil        2010     5.0   0.223838    Katrina Bowden
# 90                    Amour        2012     8.9   0.225377  Isabelle Huppert
# 91                     Rush        2013    38.0  26.903709   Chris Hemsworth
# 92                  Warrior        2011    25.0  13.651662         Tom Hardy
# 93                  Flipped        2010    14.0   1.752214  Madeline Carroll
#
#          actor_2_name            actor_3_name  actor_1_facebook_likes  \
# 89       Tyler Labine          Chelan Simmons                     948
# 90    Emmanuelle Riva  Jean-Louis Trintignant                     678
# 91       Olivia Wilde    Alexandra Maria Lara                   26000
# 92       Frank Grillo              Kevin Dunn                   27000
# 93  Rebecca De Mornay             Aidan Quinn                    1000
#
#     actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating genre_1  \
# ...

# %%
neg_profit.sort_values("profit", ascending = True, inplace = True, ignore_index = True)

neg_profit.head()
# Out:
#                          Title  title_year  budget       Gross  \
# 0                         Hugo        2011   170.0   73.820094
# 1            The Little Prince        2015    81.2    1.339152
# 2             Edge of Tomorrow        2014   178.0  100.189501
# 3                      Tangled        2010   260.0  200.807262
# 4  Scott Pilgrim vs. the World        2010    60.0   31.494270
#
#           actor_1_name     actor_2_name   actor_3_name  \
# 0  ChloÃ« Grace Moretz  Christopher Lee   Ray Winstone
# 1         Jeff Bridges     James Franco  Mackenzie Foy
# 2           Tom Cruise      Lara Pulver    Noah Taylor
# 3         Brad Garrett     Donna Murphy    M.C. Gainey
# 4        Anna Kendrick    Kieran Culkin     Ellen Wong
#
#    actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 0                   17000                 16000.0                  1000.0
# 1                   12000                 11000.0                  6000.0
# ...

# %% [markdown]
# - ### 2.3: The General Audience and the Critics

# %%
# Change the scale of MetaCritic

movies[['MetaCritic']] =  movies[['MetaCritic']]/10

movies.head()
# Out:
#                                         Title  title_year  budget       Gross  \
# 0  Star Wars: Episode VII - The Force Awakens        2015   245.0  936.662225
# 1                                The Avengers        2012   220.0  623.279547
# 2                                    Deadpool        2016    58.0  363.024263
# 3             The Hunger Games: Catching Fire        2013   130.0  424.645577
# 4                                 Toy Story 3        2010   200.0  414.984497
#
#         actor_1_name       actor_2_name           actor_3_name  \
# 0        Doug Walker         Rob Walker                      0
# 1    Chris Hemsworth  Robert Downey Jr.     Scarlett Johansson
# 2      Ryan Reynolds          Ed Skrein         Stefan Kapicic
# 3  Jennifer Lawrence    Josh Hutcherson  Sandra Ellis Lafferty
# 4          Tom Hanks  John Ratzenberger            Don Rickles
#
#    actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# ...

# %%
# Finding the average ratings

movies['Avg_rating']= (movies['MetaCritic'] + movies['IMDb_rating'])/2

#movies['Avg_rating'] = movies[['MetaCritic','IMDb_rating']].mean(axis=1)

movies.head()
# Out:
#                                         Title  title_year  budget       Gross  \
# 0  Star Wars: Episode VII - The Force Awakens        2015   245.0  936.662225
# 1                                The Avengers        2012   220.0  623.279547
# 2                                    Deadpool        2016    58.0  363.024263
# 3             The Hunger Games: Catching Fire        2013   130.0  424.645577
# 4                                 Toy Story 3        2010   200.0  414.984497
#
#         actor_1_name       actor_2_name           actor_3_name  \
# 0        Doug Walker         Rob Walker                      0
# 1    Chris Hemsworth  Robert Downey Jr.     Scarlett Johansson
# 2      Ryan Reynolds          Ed Skrein         Stefan Kapicic
# 3  Jennifer Lawrence    Josh Hutcherson  Sandra Ellis Lafferty
# 4          Tom Hanks  John Ratzenberger            Don Rickles
#
#    actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# ...

# %%
# Sorting in descending order of average rating

movies.sort_values("Avg_rating", ascending = False, inplace= True, ignore_index = True)
movies.head()
# Out:
#                    Title  title_year  budget       Gross        actor_1_name  \
# 0                Boyhood        2014     4.0   25.359200      Ellar Coltrane
# 1       12 Years a Slave        2013    20.0   56.667870  QuvenzhanÃ© Wallis
# 2             Inside Out        2015   175.0  356.454367         Amy Poehler
# 3            Toy Story 3        2010   200.0  414.984497           Tom Hanks
# 4  Manchester by the Sea        2016     9.0   47.695371       Casey Affleck
#
#          actor_2_name   actor_3_name  actor_1_facebook_likes  \
# 0   Lorelei Linklater  Libby Villari                     230
# 1       Scoot McNairy   Taran Killam                    2000
# 2        Mindy Kaling  Phyllis Smith                    1000
# 3   John Ratzenberger    Don Rickles                   15000
# 4  Michelle Williams   Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating    genre_1  \
# ...

# %%
# Finding the movies with metacritic-rating < 0.5 and also with the average rating of >= 8

UniversalAcclaim = movies[(abs(movies['MetaCritic'] - movies['IMDb_rating']) < 0.5) & (movies['Avg_rating'] >= 8)]

UniversalAcclaim.head()
# Out:
#                                          Title  title_year  budget  \
# 9                                     Whiplash        2014     3.3
# 18                            Django Unchained        2012   100.0
# 20                          Dallas Buyers Club        2013     5.0
# 26  Star Wars: Episode VII - The Force Awakens        2015   245.0
# 28                                     Arrival        2016    47.0
#
#          Gross         actor_1_name     actor_2_name     actor_3_name  \
# 9    13.092000         J.K. Simmons  Melissa Benoist     Chris Mulkey
# 18  162.804648    Leonardo DiCaprio  Christoph Waltz     Ato Essandoh
# 20   27.296514  Matthew McConaughey  Jennifer Garner     Denis O'Hare
# 26  936.662225          Doug Walker       Rob Walker                0
# 28  100.546139            Amy Adams    Jeremy Renner  Forest Whitaker
#
#     actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# ...

# %% [markdown]
# - ### 2.4: Finding the Most Popular Trios - I

# %%
trios_1 = (movies[['actor_1_name','actor_2_name','actor_3_name','actor_1_facebook_likes','actor_2_facebook_likes','actor_3_facebook_likes']])
trios_1.head()
# Out:
#          actor_1_name        actor_2_name   actor_3_name  \
# 0      Ellar Coltrane   Lorelei Linklater  Libby Villari
# 1  QuvenzhanÃ© Wallis       Scoot McNairy   Taran Killam
# 2         Amy Poehler        Mindy Kaling  Phyllis Smith
# 3           Tom Hanks   John Ratzenberger    Don Rickles
# 4       Casey Affleck  Michelle Williams   Kyle Chandler
#
#    actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes
# 0                     230                   193.0                   127.0
# 1                    2000                   660.0                   500.0
# 2                    1000                   767.0                   384.0
# 3                   15000                  1000.0                   721.0
# 4                     518                 71000.0                  3300.0

# %%
trios_1['Total_fb_like'] = trios_1['actor_1_facebook_likes'] + trios_1['actor_2_facebook_likes'] + trios_1['actor_3_facebook_likes']

trios_1.head()
# Out:
#          actor_1_name        actor_2_name   actor_3_name  \
# 0      Ellar Coltrane   Lorelei Linklater  Libby Villari
# 1  QuvenzhanÃ© Wallis       Scoot McNairy   Taran Killam
# 2         Amy Poehler        Mindy Kaling  Phyllis Smith
# 3           Tom Hanks   John Ratzenberger    Don Rickles
# 4       Casey Affleck  Michelle Williams   Kyle Chandler
#
#    actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 0                     230                   193.0                   127.0
# 1                    2000                   660.0                   500.0
# 2                    1000                   767.0                   384.0
# 3                   15000                  1000.0                   721.0
# 4                     518                 71000.0                  3300.0
#
#    Total_fb_like
# 0          550.0
# 1         3160.0
# 2         2151.0
# 3        16721.0
# 4        74818.0

# %%
top_5_popular = trios_1.sort_values('Total_fb_like',ascending = False, ignore_index= True).head()
top_5_popular
# Out:
#         actor_1_name        actor_2_name          actor_3_name  \
# 0          Dev Patel       Nicole Kidman           Rooney Mara
# 1  Leonardo DiCaprio           Tom Hardy  Joseph Gordon-Levitt
# 2  Jennifer Lawrence      Peter Dinklage          Hugh Jackman
# 3      Casey Affleck  Michelle Williams          Kyle Chandler
# 4          Tom Hardy      Christian Bale  Joseph Gordon-Levitt
#
#    actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 0                   33000                 96000.0                  9800.0
# 1                   29000                 27000.0                 23000.0
# 2                   34000                 22000.0                 20000.0
# 3                     518                 71000.0                  3300.0
# 4                   27000                 23000.0                 23000.0
#
#    Total_fb_like
# 0       138800.0
# 1        79000.0
# 2        76000.0
# 3        74818.0
# 4        73000.0

# %%
# the top 5 popular trios and their names in a list.

top_5_trios_name = top_5_popular[['actor_1_name','actor_2_name','actor_3_name']].values.tolist()

top_5_trios_name
# Out:
# [['Dev Patel', 'Nicole Kidman', 'Rooney Mara'],
#  ['Leonardo DiCaprio', 'Tom Hardy', 'Joseph Gordon-Levitt'],
#  ['Jennifer Lawrence', 'Peter Dinklage', 'Hugh Jackman'],
#  ['Casey Affleck', 'Michelle Williams ', 'Kyle Chandler'],
#  ['Tom Hardy', 'Christian Bale', 'Joseph Gordon-Levitt']]

# %% [markdown]
# - ### 2.5: Runtime Analysis
#
# There is a column named `Runtime` in the dataframe which primarily shows the length of the movie. It might be intersting to see how this variable this distributed. Ploting a `histogram` or `distplot` of seaborn to find the `Runtime` range most of the movies fall into.

# %%
# Runtime histogram/density plot

plt.figure(figsize = [10,8])

#plt.hist(movies['Runtime'], bins = 10)

sns.distplot(movies['Runtime'], kde = False, color= 'Green', hist_kws = {'edgecolor':'Black'})

plt.title("Runtime analysis for movies", fontdict = {'fontsize': 15, 'fontweight' : 10, 'color' : 'Black'})
plt.xlabel('Runtime', fontdict = {'fontsize' : 12, 'fontweight' : 5, 'color' :  'Blue'})
plt.ylabel('Number of Movies', fontdict = {'fontsize' : 12, 'fontweight': 5, 'color' : 'Blue'})

tick_values=np.arange(100, 200,20)
tick_label = ['100min','120min','140min','160min','180min']

plt.xticks(tick_values, tick_label)

plt.show()

# %% [markdown]
# - ### 2.6: R-Rated Movies
#
# Although R rated movies are restricted movies for the under 18 age group, still there are vote counts from that age group. Among all the R rated movies that have been voted by the under-18 age group, find the top 10 movies that have the highest number of votes i.e.`CVotesU18` from the `movies` dataframe. Savings these in a dataframe named `PopularR`.

# %%
# Write your code here

R_rated = movies[movies['content_rating'] == 'R']

R_rated.head()
# Out:
#                    Title  title_year  budget      Gross  \
# 0                Boyhood        2014     4.0  25.359200
# 1       12 Years a Slave        2013    20.0  56.667870
# 4  Manchester by the Sea        2016     9.0  47.695371
# 7              Spotlight        2015    20.0  44.988180
# 8        Before Midnight        2013     3.0   8.114507
#
#                actor_1_name        actor_2_name            actor_3_name  \
# 0            Ellar Coltrane   Lorelei Linklater           Libby Villari
# 1        QuvenzhanÃ© Wallis       Scoot McNairy            Taran Killam
# 4             Casey Affleck  Michelle Williams            Kyle Chandler
# 7              Billy Crudup      Jamey Sheridan      Brian d'Arcy James
# 8  Seamus Davey-Fitzpatrick        Ariane Labed  Athina Rachel Tsangari
#
#    actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 0                     230                   193.0                   127.0
# ...

# %%
PopularR = R_rated.sort_values(by ='CVotesU18', ascending = False, ignore_index = True).head(10)

PopularR.head()
# Out:
#                      Title  title_year  budget       Gross       actor_1_name  \
# 0                 Deadpool        2016    58.0  363.024263      Ryan Reynolds
# 1  The Wolf of Wall Street        2013   100.0  116.866727  Leonardo DiCaprio
# 2         Django Unchained        2012   100.0  162.804648  Leonardo DiCaprio
# 3       Mad Max: Fury Road        2015   150.0  153.629485          Tom Hardy
# 4                 Whiplash        2014     3.3   13.092000       J.K. Simmons
#
#           actor_2_name    actor_3_name  actor_1_facebook_likes  \
# 0            Ed Skrein  Stefan Kapicic                   16000
# 1  Matthew McConaughey     Jon Favreau                   29000
# 2      Christoph Waltz    Ato Essandoh                   29000
# 3      Charlize Theron    ZoÃ« Kravitz                   27000
# 4      Melissa Benoist    Chris Mulkey                   24000
#
#    actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating    genre_1  \
# ...

# %% [markdown]
# ## Task 3 : Demographic analysis
#
# If you take a look at the last columns in the dataframe, most of these are related to demographics of the voters (in the last subtask, i.e., 2.8, you made use one of these columns - CVotesU18). We also have three genre columns indicating the genres of a particular movie. We will extensively use these columns for the third and the final stage of our assignment wherein we will analyse the voters across all demographics and also see how these vary across various genres. So without further ado, let's get started with `demographic analysis`.

# %% [markdown]
# -  ###   3.1 Combine the Dataframe by Genres
#
# There are 3 columns in the dataframe - `genre_1`, `genre_2`, and `genre_3`. As a part of this subtask, you need to aggregate a few values over these 3 columns.

# %%
movies.head()
# Out:
#                    Title  title_year  budget       Gross        actor_1_name  \
# 0                Boyhood        2014     4.0   25.359200      Ellar Coltrane
# 1       12 Years a Slave        2013    20.0   56.667870  QuvenzhanÃ© Wallis
# 2             Inside Out        2015   175.0  356.454367         Amy Poehler
# 3            Toy Story 3        2010   200.0  414.984497           Tom Hanks
# 4  Manchester by the Sea        2016     9.0   47.695371       Casey Affleck
#
#          actor_2_name   actor_3_name  actor_1_facebook_likes  \
# 0   Lorelei Linklater  Libby Villari                     230
# 1       Scoot McNairy   Taran Killam                    2000
# 2        Mindy Kaling  Phyllis Smith                    1000
# 3   John Ratzenberger    Don Rickles                   15000
# 4  Michelle Williams   Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating    genre_1  \
# ...

# %%
# Creating the dataframe df_by_genre

df_by_genre = movies.drop(movies.loc[:, 'Title':'IMDb_rating'].columns, axis = 1)

df_by_genre = df_by_genre.drop(df_by_genre.loc[:, 'content_rating':'Avg_rating'].columns, axis = 1)

df_by_genre = df_by_genre.drop(['MetaCritic','Runtime'], axis = 1)

df_by_genre.head()
# Out:
#      genre_1    genre_2  genre_3  CVotes10  CVotes09  CVotes08  CVotes07  \
# 0      Drama        NaN      NaN     49673     62055     76838     52238
# 1  Biography      Drama  History     75556    126223    161460     83070
# 2  Animation  Adventure   Comedy     87509    113244    119801     67153
# 3  Animation  Adventure   Comedy    139773    149992    158704     88289
# 4      Drama        NaN      NaN     18191     33532     46596     29626
#
#    CVotes06  CVotes05  CVotes04  CVotes03  CVotes02  CVotes01  CVotesMale  \
# 0     23789     10431      4906      3071      2248      5086      183807
# 1     27231      9603      4021      2420      1785      4739      313823
# 2     24210      8542      3349      1872      1123      3450      244433
# 3     31291     11850      4859      2932      2119      6586      389014
# 4     11879      4539      1976      1233       888      1834       92452
#
#    CVotesFemale  CVotesU18  CVotesU18M  CVotesU18F  CVotes1829  CVotes1829M  \
# ...

# %%
df_by_genre.shape
# Out:
# (100, 47)

# %%
# Creating a column cnt and initialize it to 1
df_by_genre['cnt'] = 1
df_by_genre.head()
# Out:
#      genre_1    genre_2  genre_3  CVotes10  CVotes09  CVotes08  CVotes07  \
# 0      Drama        NaN      NaN     49673     62055     76838     52238
# 1  Biography      Drama  History     75556    126223    161460     83070
# 2  Animation  Adventure   Comedy     87509    113244    119801     67153
# 3  Animation  Adventure   Comedy    139773    149992    158704     88289
# 4      Drama        NaN      NaN     18191     33532     46596     29626
#
#    CVotes06  CVotes05  CVotes04  CVotes03  CVotes02  CVotes01  CVotesMale  \
# 0     23789     10431      4906      3071      2248      5086      183807
# 1     27231      9603      4021      2420      1785      4739      313823
# 2     24210      8542      3349      1872      1123      3450      244433
# 3     31291     11850      4859      2932      2119      6586      389014
# 4     11879      4539      1976      1233       888      1834       92452
#
#    CVotesFemale  CVotesU18  CVotesU18M  CVotesU18F  CVotes1829  CVotes1829M  \
# ...

# %%
# Grouping the movies by individual genres

df_by_g1 = df_by_genre.groupby('genre_1').sum()

df_by_g1.head()
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_1
# Action      2928407   3261919   4247693   2662020    986774    364234
# Adventure   1058779   1179818   1560541    966275    365486    136985
# Animation    681562    798227   1153214    722782    251076     83069
# Biography    666831   1088430   1654704    962977    306247    100005
# Comedy       371217    496905    770395    518566    205434     81933
#
#            CVotes04  CVotes03  CVotes02  CVotes01  CVotesMale  CVotesFemale  \
# genre_1
# Action       156150     89483     61975    162426     9994618       1858890
# Adventure     58559     33174     22018     48100     3535070        802902
# Animation     30718     15733     10026     25193     2282985        724844
# Biography     38874     21536     15365     37469     3151311        790809
# Comedy        35788     20965     15286     33241     1573480        527333
#
# ...

# %%
# Grouping the movies by individual genres

df_by_g2 = df_by_genre.groupby('genre_2').sum()

df_by_g2.head()
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_2
# Action       238060    285510    430062    260106     88580     29250
# Adventure   2297820   2548864   3271725   2055600    758009    272735
# Biography    185172    313178    576374    370003    119348     38643
# Comedy       428995    624720    854162    512668    193916     76752
# Crime         19576     40247     85359     64633     24920      8548
#
#            CVotes04  CVotes03  CVotes02  CVotes01  CVotesMale  CVotesFemale  \
# genre_2
# Action        10820      5521      3598      8821      842416        246520
# Adventure    113691     64623     44121    116937     7382329       1656482
# Biography     14844      7974      5248     13828     1178160        196080
# Comedy        35193     20995     14798     30509     1839470        422379
# Crime          3261      1669       970      1689      178321         21448
#
# ...

# %%
# Grouping the movies by individual genres

df_by_g3 = df_by_genre.groupby('genre_3').sum()

df_by_g3.head()
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_3
# Adventure    238060    285510    430062    260106     88580     29250
# Comedy       583404    653362    882294    559835    200937     68167
# Crime        171660    236650    250667    129164     46715     18682
# Drama        400221    680085   1167327    748493    258717     88338
# Family        29228     40728     77893     62936     27932     11179
#
#            CVotes04  CVotes03  CVotes02  CVotes01  CVotesMale  CVotesFemale  \
# genre_3
# Adventure     10820      5521      3598      8821      842416        246520
# Comedy        26488     14258      9307     24617     1810083        548576
# Crime          8674      5854      4258      9689      559564        123698
# Drama         35439     19075     12475     26948     2364247        454437
# Family         4664      2674      1700      3023      179655         47795
#
# ...

# %%
# Adding the grouped data frames and store it in a new data frame

add_1 = df_by_g1.add(df_by_g2, fill_value = 0)

df_add = add_1.add(df_by_g3, fill_value = 0)

df_add.head()
# Out:
#             CVotes10   CVotes09   CVotes08   CVotes07   CVotes06  CVotes05  \
# Action     3166467.0  3547429.0  4677755.0  2922126.0  1075354.0  393484.0
# Adventure  3594659.0  4014192.0  5262328.0  3281981.0  1212075.0  438970.0
# Animation   681562.0   798227.0  1153214.0   722782.0   251076.0   83069.0
# Biography   852003.0  1401608.0  2231078.0  1332980.0   425595.0  138648.0
# Comedy     1383616.0  1774987.0  2506851.0  1591069.0   600287.0  226852.0
#
#            CVotes04  CVotes03  CVotes02  CVotes01  CVotesMale  CVotesFemale  \
# Action     166970.0   95004.0   65573.0  171247.0  10837034.0     2105410.0
# Adventure  183070.0  103318.0   69737.0  173858.0  11759815.0     2705904.0
# Animation   30718.0   15733.0   10026.0   25193.0   2282985.0      724844.0
# Biography   53718.0   29510.0   20613.0   51297.0   4329471.0      986889.0
# Comedy      97469.0   56218.0   39391.0   88367.0   5223033.0     1498288.0
#
# ...

# %%
# Extracting genres with atleast 10 occurences

genre_top10 = df_add[df_add['cnt']>= 10]

genre_top10
# Out:
#             CVotes10   CVotes09   CVotes08   CVotes07   CVotes06  CVotes05  \
# Action     3166467.0  3547429.0  4677755.0  2922126.0  1075354.0  393484.0
# Adventure  3594659.0  4014192.0  5262328.0  3281981.0  1212075.0  438970.0
# Animation   681562.0   798227.0  1153214.0   722782.0   251076.0   83069.0
# Biography   852003.0  1401608.0  2231078.0  1332980.0   425595.0  138648.0
# Comedy     1383616.0  1774987.0  2506851.0  1591069.0   600287.0  226852.0
# Crime       574526.0   967118.0  1419495.0   821390.0   278391.0   98690.0
# Drama      3404438.0  4935375.0  7107053.0  4319700.0  1529356.0  552312.0
# Romance     549959.0   689492.0  1069280.0   712841.0   281289.0  110901.0
# Sci-Fi     2325284.0  2530855.0  3002994.0  1802098.0   671811.0  254175.0
# Thriller   1081701.0  1465491.0  1993378.0  1175799.0   416046.0  149953.0
#
#            CVotes04  CVotes03  CVotes02  CVotes01  CVotesMale  CVotesFemale  \
# ...

# %%
# Taking the mean for every column by dividing with cnt 

genre_top10.iloc[:, 0:-1] = genre_top10.iloc[:, 0:-1].div(genre_top10['cnt'], axis = 0)

genre_top10
# Out:
#                 CVotes10       CVotes09       CVotes08       CVotes07  \
# Action     102144.096774  114433.193548  150895.322581   94262.129032
# Adventure   94596.289474  105636.631579  138482.315789   86367.921053
# Animation   61960.181818   72566.090909  104837.636364   65707.454545
# Biography   47333.500000   77867.111111  123948.777778   74054.444444
# Comedy      60157.217391   77173.347826  108993.521739   69176.913043
# Crime       52229.636364   87919.818182  129045.000000   74671.818182
# Drama       52375.969231   75928.846154  109339.276923   66456.923077
# Romance     42304.538462   53037.846154   82252.307692   54833.923077
# Sci-Fi     136781.411765  148873.823529  176646.705882  106005.764706
# Thriller    83207.769231  112730.076923  153336.769231   90446.076923
#
#                CVotes06      CVotes05     CVotes04     CVotes03     CVotes02  \
# Action     34688.838710  12693.032258  5386.129032  3064.645161  2115.258065
# ...

# %%
# Rounding off the columns of Votes to two decimals

genre_top10.loc[:,'VotesM':'VotesnUS'] = round(genre_top10.loc[:,'VotesM':'VotesnUS'],2)

genre_top10
# Out:
#                 CVotes10       CVotes09       CVotes08       CVotes07  \
# Action     102144.096774  114433.193548  150895.322581   94262.129032
# Adventure   94596.289474  105636.631579  138482.315789   86367.921053
# Animation   61960.181818   72566.090909  104837.636364   65707.454545
# Biography   47333.500000   77867.111111  123948.777778   74054.444444
# Comedy      60157.217391   77173.347826  108993.521739   69176.913043
# Crime       52229.636364   87919.818182  129045.000000   74671.818182
# Drama       52375.969231   75928.846154  109339.276923   66456.923077
# Romance     42304.538462   53037.846154   82252.307692   54833.923077
# Sci-Fi     136781.411765  148873.823529  176646.705882  106005.764706
# Thriller    83207.769231  112730.076923  153336.769231   90446.076923
#
#                CVotes06      CVotes05     CVotes04     CVotes03     CVotes02  \
# Action     34688.838710  12693.032258  5386.129032  3064.645161  2115.258065
# ...

# %%
# Converting CVotes to int type
genre_top10.loc[:,'CVotes10':'CVotesnUS'] = genre_top10.loc[:,'CVotes10':'CVotesnUS'].astype('int64')

genre_top10
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# Action     102144.0  114433.0  150895.0   94262.0   34688.0   12693.0
# Adventure   94596.0  105636.0  138482.0   86367.0   31896.0   11551.0
# Animation   61960.0   72566.0  104837.0   65707.0   22825.0    7551.0
# Biography   47333.0   77867.0  123948.0   74054.0   23644.0    7702.0
# Comedy      60157.0   77173.0  108993.0   69176.0   26099.0    9863.0
# Crime       52229.0   87919.0  129045.0   74671.0   25308.0    8971.0
# Drama       52375.0   75928.0  109339.0   66456.0   23528.0    8497.0
# Romance     42304.0   53037.0   82252.0   54833.0   21637.0    8530.0
# Sci-Fi     136781.0  148873.0  176646.0  106005.0   39518.0   14951.0
# Thriller    83207.0  112730.0  153336.0   90446.0   32003.0   11534.0
#
#            CVotes04  CVotes03  CVotes02  CVotes01  CVotesMale  CVotesFemale  \
# Action       5386.0    3064.0    2115.0    5524.0    349581.0       67916.0
# ...

# %% [markdown]
# If you take a look at the final dataframe that you have gotten, you will see that you now have the complete information about all the demographic (Votes- and CVotes-related) columns across the top 10 genres. We can use this dataset to extract exciting insights about the voters!

# %% [markdown]
# -  ### 3.2: Genre Counts!
#
# Now let's derive some insights from this data frame. Make a bar chart plotting different genres vs cnt using seaborn.

# %%
# Countplot for genres

plt.figure(figsize = [10,8])

sns.barplot(x= genre_top10.index.values ,y = genre_top10['cnt'], data = genre_top10)

plt.title("Counts for Different Genres", fontdict = {'fontsize': 15, 'fontweight' : 10, 'color' : 'Green'})
plt.xlabel('Genres', fontdict = {'fontsize' : 12, 'fontweight' : 5, 'color' :  'Blue'})
plt.ylabel('Count', fontdict = {'fontsize' : 12, 'fontweight': 5, 'color' : 'Blue'})

plt.show()

# %% [markdown]
# -  ### 3.3: Gender and Genre
#
# If you have closely looked at the Votes- and CVotes-related columns, you might have noticed the suffixes `F` and `M` indicating Female and Male. Since we have the vote counts for both males and females, across various age groups, let's now see how the popularity of genres vary between the two genders in the dataframe.

# %%
# 1st set of heat maps for CVotes-related columns

fig, (ax_1, ax_2, ax_3) = plt.subplots(nrows = 1,ncols = 3, gridspec_kw= {'width_ratios': [1,1,0.08]}, figsize = (12,8))

male_group = sns.heatmap(genre_top10[["CVotesU18M","CVotes1829M","CVotes3044M","CVotes45AM"]], cmap = "Greens", annot=True, fmt = 'g', cbar = True ,ax= ax_1)
male_group.set_ylabel("Genres", fontsize = 10)
male_group.set_xlabel("Male Age Group", fontsize = 10)

ax_1.set_title('\n The Popularity of Genres Between The Two Genders For CVotes\n',loc= 'left', fontdict = {'fontsize': 20, 'fontweight' : 10, 'color' : 'Black'} )

female_group = sns.heatmap(genre_top10[["CVotesU18F","CVotes1829F","CVotes3044F","CVotes45AF"]], cmap = "Greens", annot = True, fmt = 'g', cbar_ax = ax_3, ax = ax_2)
female_group.set_ylabel('')
female_group.set_xlabel("Female Age Group", fontsize = 10)
female_group.set_yticks([])


t1 = male_group.get_xticklabels()
male_group.set_xticklabels(t1, rotation = 90)

t2 = male_group.get_yticklabels()
male_group.set_yticklabels(t2, rotation = 0)

t3 = female_group.get_xticklabels()
female_group.set_xticklabels(t3, rotation = 90)

plt.show()

# %% [markdown]
# **`Inferences:`** A few inferences that can be seen from the heatmap above is that males have voted more than females, and Sci-Fi appears to be most popular among the 18-29 age group irrespective of their gender.
#
# - Inference 1: For male and female, age between 18-29 voted mostly for Sci-Fi Genres.
# - Inference 2: For male romance genres is least voted for all age group. For female most votes goes for Sci-Fi genres for all age groups
# - Inference 3: Male under 18 have voted more then female under 18
# - Inference 4: For male and female, age between 18-29 & 30-44 have voted mostly then under 18 and 45 after for all genres

# %%
# 2nd set of heat maps for Votes-related columns

fig, (ax_1, ax_2, ax_3) = plt.subplots(nrows = 1, ncols = 3, gridspec_kw= {'width_ratios': [1,1,0.08]}, figsize = (12,8))

male_group_2 = sns.heatmap(genre_top10[["VotesU18M","Votes1829M","Votes3044M","Votes45AM"]], cmap = "Blues", annot=True, fmt = 'g',cbar =True ,ax= ax_1)
male_group_2.set_ylabel("Genres", fontsize = 10)
male_group_2.set_xlabel("Male Age Group", fontsize = 10)
ax_1.set_title('\n The Popularity of Genres Between The Two Genders For Votes\n',loc= 'left', fontdict = {'fontsize': 20, 'fontweight' : 10, 'color' : 'Black'} )
female_group_2 = sns.heatmap(genre_top10[["VotesU18F","Votes1829F","Votes3044F","Votes45AF"]], cmap = "Blues", annot = True, fmt = 'g', cbar_ax = ax_3, ax = ax_2)
female_group_2.set_ylabel(' ')
female_group_2.set_xlabel("female Age Group", fontsize = 10)
female_group_2.set_yticks([])


t1_2 = male_group_2.get_xticklabels()
male_group_2.set_xticklabels(t1_2, rotation = 90)

t2_2 = male_group_2.get_yticklabels()
male_group_2.set_yticklabels(t2_2, rotation = 0)

t3_2 = female_group_2.get_xticklabels()
female_group_2.set_xticklabels(t3_2, rotation = 90)

plt.show()

# %% [markdown]
# **`Inferences:`** Sci-Fi appears to be the highest rated genre in the age group of U18 for both males and females. Also, females in this age group have rated it a bit higher than the males in the same age group.
#
# - Inference 1: for female age under 18 voted mostly for Action, adventure, Animation and maximum votes for Sci-Fi genres.
# - Inference 2: for Male and female of age group 30-44 & after 45 have voted less compare to other age group.
# - Inference 3: other then few exceptions as age increases voting is get decreases.
# - Inference 4: for all age group, males have most votes for Sci-Fi genres, for females Sci-fi & animation genres have high votes.

# %% [markdown]
# -  ### 3.4: US vs non-US Cross Analysis
#
# The dataset contains both the US and non-US movies. Let's analyse how both the US and the non-US voters have responded to the US and the non-US movies.

# %%
# Creating IFUS column
movies['IFUS'] = movies['Country'].apply(lambda x: 'USA' if x == 'USA' else 'non-USA')
movies.head()
# Out:
#                    Title  title_year  budget       Gross        actor_1_name  \
# 0                Boyhood        2014     4.0   25.359200      Ellar Coltrane
# 1       12 Years a Slave        2013    20.0   56.667870  QuvenzhanÃ© Wallis
# 2             Inside Out        2015   175.0  356.454367         Amy Poehler
# 3            Toy Story 3        2010   200.0  414.984497           Tom Hanks
# 4  Manchester by the Sea        2016     9.0   47.695371       Casey Affleck
#
#          actor_2_name   actor_3_name  actor_1_facebook_likes  \
# 0   Lorelei Linklater  Libby Villari                     230
# 1       Scoot McNairy   Taran Killam                    2000
# 2        Mindy Kaling  Phyllis Smith                    1000
# 3   John Ratzenberger    Don Rickles                   15000
# 4  Michelle Williams   Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating    genre_1  \
# ...

# %%
# Box plot - 1: CVotesUS(y) vs IFUS(x)

plt.figure(figsize= [10,10])

fig, axes = plt.subplots(nrows =1, ncols =2)

box_1 = sns.boxplot(x='IFUS', y='CVotesUS', data= movies, ax = axes[0])
box_1.axes.set_title('Votes from USA peoples', fontsize = 10, color= "Green")

box_1.set_xlabel('IFUS', fontsize = 10)
box_1.set_ylabel('CVotesUS', fontsize = 10)


box_2 = sns.boxplot(x='IFUS', y='CVotesnUS', data= movies, ax = axes[1])
box_2.axes.set_title('Votes from non-USA peoples', fontsize = 10, color='Blue')

box_2.set_xlabel('IFUS', fontsize = 10)
box_2.set_ylabel('CVotesnUS', fontsize = 10)

plt.tight_layout()

plt.show()

# %% [markdown]
# **`Inferences:`**
# - Inference 1: From both boxplots we can see outliers for USA movies.
# - Inference 2: Votes from USA & non-USA peoples, for movies from USA is greater than non-USA movies.

# %%
# Box plot - 2: VotesUS(y) vs IFUS(x)

plt.figure(figsize= [10,10])

fig, axes = plt.subplots(nrows =1, ncols =2)

box_1 = sns.boxplot(x='IFUS', y='VotesUS', data= movies, ax = axes[0])
box_1.axes.set_title('Votes from USA peoples', fontsize = 10, color= "Blue")

box_1.set_xlabel('IFUS', fontsize = 10)
box_1.set_ylabel('VotesUS', fontsize = 10)


box_2 = sns.boxplot(x='IFUS', y='VotesnUS', data= movies, ax = axes[1])
box_2.axes.set_title('Votes from non-USA peoples', fontsize = 10, color='Green')

box_2.set_xlabel('IFUS', fontsize = 10)
box_2.set_ylabel('VotesnUS', fontsize = 10)

plt.tight_layout()
plt.show()

# %% [markdown]
# **`Inferences:`**
# - Inference 1: Median of votes is greater in USA movies compare to non-USA movies in both box plots.
# - Inference 2: Both USA & non-USA people have voted higher in rating for USA movies compare to non-USA movies.

# %% [markdown]
# -  ### 3.5:  Top 1000 Voters Vs Genres
#
# We have also observed the column `CVotes1000`. This column represents the top 1000 voters on IMDb and gives the count for the number of these voters who have voted for a particular movie. Let's see how these top 1000 voters have voted across the genres.

# %%
# Sorting by CVotes1000

genre_CVotes1000= genre_top10.sort_values('CVotes1000', ascending= False)

genre_CVotes1000
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# Sci-Fi     136781.0  148873.0  176646.0  106005.0   39518.0   14951.0
# Action     102144.0  114433.0  150895.0   94262.0   34688.0   12693.0
# Thriller    83207.0  112730.0  153336.0   90446.0   32003.0   11534.0
# Adventure   94596.0  105636.0  138482.0   86367.0   31896.0   11551.0
# Crime       52229.0   87919.0  129045.0   74671.0   25308.0    8971.0
# Comedy      60157.0   77173.0  108993.0   69176.0   26099.0    9863.0
# Biography   47333.0   77867.0  123948.0   74054.0   23644.0    7702.0
# Drama       52375.0   75928.0  109339.0   66456.0   23528.0    8497.0
# Animation   61960.0   72566.0  104837.0   65707.0   22825.0    7551.0
# Romance     42304.0   53037.0   82252.0   54833.0   21637.0    8530.0
#
#            CVotes04  CVotes03  CVotes02  CVotes01  CVotesMale  CVotesFemale  \
# Sci-Fi       6583.0    3876.0    2715.0    6731.0    422437.0       83618.0
# ...

# %%
# Bar plot

plt.figure(figsize = [10,5])

sns.barplot(y= genre_CVotes1000.CVotes1000, x= genre_CVotes1000.index)

plt.title('Top 1000 Voters Vs. Genre', fontsize = 12, color = 'Green')
plt.xlabel('Genre', fontsize = 10, color = 'Blue')
plt.ylabel('CVotes1000', fontsize = 10, color = 'Blue')

plt.show()

# %% [markdown]
# **`Inferences:`**

# %% [markdown]
# - The genre `Romance` seems to be most unpopular among the top 1000 voters.
# - Sci-Fi is most popular in top 1000 voters
# - Action, Thriller and Adventure are just popular after Sci-Fi movies just like in heatmap these four genres.
# - For Sci-Fi movies number of movies are less, but voted highest rating among all the genres.
